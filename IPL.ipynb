# %% [markdown]
# <a href="https://colab.research.google.com/github/shanmu2108/IPL-data/blob/main/IPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
match_data = pd.read_csv("/IPL Matches 2008-2020.csv")
ball_data = pd.read_csv("/IPL Ball-by-Ball 2008-2020.csv")

# %%
match_data.head()
# Out:
#        id        city        date  ... method    umpire1         umpire2
# 0  335982   Bangalore  18-04-2008  ...    NaN  Asad Rauf     RE Koertzen
# 1  335983  Chandigarh  19-04-2008  ...    NaN  MR Benson      SL Shastri
# 2  335984       Delhi  19-04-2008  ...    NaN  Aleem Dar  GA Pratapkumar
# 3  335985      Mumbai  20-04-2008  ...    NaN   SJ Davis       DJ Harper
# 4  335986     Kolkata  20-04-2008  ...    NaN  BF Bowden     K Hariharan
#
# [5 rows x 17 columns]

# %%
ball_data.head()
# Out:
#        id  inning  ...           batting_team                 bowling_team
# 0  335982       1  ...  Kolkata Knight Riders  Royal Challengers Bangalore
# 1  335982       1  ...  Kolkata Knight Riders  Royal Challengers Bangalore
# 2  335982       1  ...  Kolkata Knight Riders  Royal Challengers Bangalore
# 3  335982       1  ...  Kolkata Knight Riders  Royal Challengers Bangalore
# 4  335982       1  ...  Kolkata Knight Riders  Royal Challengers Bangalore
#
# [5 rows x 18 columns]

# %%
match_data.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
ball_data.isnull().sum()
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# dtype: int64

# %%
match_data.shape
# Out:
# (816, 17)

# %%
ball_data.shape
# Out:
# (193468, 18)

# %%
match_data.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
print("tot no of match played:", match_data.shape[0])
print(" the  cities in which matches are  played",match_data['city'].unique())
# Out:
# tot no of match played: 816
#  the  cities in which matches are  played ['Bangalore' 'Chandigarh' 'Delhi' 'Mumbai' 'Kolkata' 'Jaipur' 'Hyderabad'
#  'Chennai' 'Cape Town' 'Port Elizabeth' 'Durban' 'Centurion' 'East London'
#  'Johannesburg' 'Kimberley' 'Bloemfontein' 'Ahmedabad' 'Cuttack' 'Nagpur'
#  'Dharamsala' 'Kochi' 'Indore' 'Visakhapatnam' 'Pune' 'Raipur' 'Ranchi'
#  'Abu Dhabi' nan 'Rajkot' 'Kanpur' 'Bengaluru' 'Dubai' 'Sharjah']

# %%
print("total no of team",match_data['team1'].unique())
# Out:
# total no of team ['Royal Challengers Bangalore' 'Kings XI Punjab' 'Delhi Daredevils'
#  'Mumbai Indians' 'Kolkata Knight Riders' 'Rajasthan Royals'
#  'Deccan Chargers' 'Chennai Super Kings' 'Kochi Tuskers Kerala'
#  'Pune Warriors' 'Sunrisers Hyderabad' 'Gujarat Lions'
#  'Rising Pune Supergiants' 'Rising Pune Supergiant' 'Delhi Capitals']

# %%
match_data['season']=pd.DatetimeIndex(match_data['date']).year
match_data.head()
# Out:
#        id        city        date  ...    umpire1         umpire2  season
# 0  335982   Bangalore  18-04-2008  ...  Asad Rauf     RE Koertzen    2008
# 1  335983  Chandigarh  19-04-2008  ...  MR Benson      SL Shastri    2008
# 2  335984       Delhi  19-04-2008  ...  Aleem Dar  GA Pratapkumar    2008
# 3  335985      Mumbai  20-04-2008  ...   SJ Davis       DJ Harper    2008
# 4  335986     Kolkata  20-04-2008  ...  BF Bowden     K Hariharan    2008
#
# [5 rows x 18 columns]

# %%
match_per_season=match_data.groupby(['season'])['id'].count().reset_index().rename(columns={'id':'matches'})
match_per_season
# Out:
#     season  matches
# 0     2008       58
# 1     2009       57
# 2     2010       60
# 3     2011       73
# 4     2012       74
# 5     2013       76
# 6     2014       60
# 7     2015       59
# 8     2016       60
# 9     2017       59
# 10    2018       60
# 11    2019       60
# 12    2020       60

# %%
sns.countplot(match_data['season'])
plt.xticks(rotation=45,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("season",fontsize=10)
plt.ylabel("matchs",fontsize=10)
plt.title("no of matches played in each season",fontsize=15,fontweight='bold')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'no of matches played in each season')

# %%
season_data=match_data[['id','season']].merge(ball_data,left_on='id',right_on='id',how='left').drop('id',axis=1)
season_data.head()
# Out:
#    season  inning  ...           batting_team                 bowling_team
# 0    2008       1  ...  Kolkata Knight Riders  Royal Challengers Bangalore
# 1    2008       1  ...  Kolkata Knight Riders  Royal Challengers Bangalore
# 2    2008       1  ...  Kolkata Knight Riders  Royal Challengers Bangalore
# 3    2008       1  ...  Kolkata Knight Riders  Royal Challengers Bangalore
# 4    2008       1  ...  Kolkata Knight Riders  Royal Challengers Bangalore
#
# [5 rows x 18 columns]

# %%
season=season_data.groupby(['season'])['total_runs'].sum().reset_index()
p=season.set_index('season')
ax = plt.axes()
ax.set(facecolor = "grey")
sns.lineplot(data=p,palette="magma") 
plt.title('Total runs in each season',fontsize=12,fontweight="bold")
plt.show()

# %%
toss=match_data['toss_winner'].value_counts()
ax = plt.axes()
ax.set(facecolor = "grey")
sns.set(rc={'figure.figsize':(15,10)},style='darkgrid')
ax.set_title('No. of tosses won by each team',fontsize=15,fontweight="bold")
sns.barplot(y=toss.index, x=toss, orient='h',palette="magma",saturation=1)
plt.xlabel('# of tosses won')
plt.ylabel('Teams')
plt.show()

# %%
runs = ball_data.groupby(['batsman'])['batsman_runs'].sum().reset_index()
runs.columns = ['Batsman', 'runs']
y = runs.sort_values(by='runs', ascending = False).head(10).reset_index().drop('index', axis=1)
y
# Out:
#           Batsman  runs
# 0         V Kohli  5878
# 1        SK Raina  5368
# 2       DA Warner  5254
# 3       RG Sharma  5230
# 4        S Dhawan  5197
# 5  AB de Villiers  4849
# 6        CH Gayle  4772
# 7        MS Dhoni  4632
# 8      RV Uthappa  4607
# 9       G Gambhir  4217

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
sns.barplot(x=y['Batsman'],y=y['runs'],palette='rocket',saturation=1)
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('\n Player',fontsize=15)
plt.ylabel('Total Runs',fontsize=15)
plt.title('Top 10 run scorers in IPL',fontsize=15,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Top 10 run scorers in IPL')
